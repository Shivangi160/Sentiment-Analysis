# %%
## Library
## NLTK - Natural Language Tool Kit
## Package in NTLK - Vader_Lexicon - Developed by FB for Sentiment Analysis

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('good')
# Out:
# {'compound': 0.4404, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0}

# %%
sia.polarity_scores('Best')
# Out:
# {'compound': 0.6369, 'neg': 0.0, 'neu': 0.0, 'pos': 1.0}

# %%
sia.polarity_scores('best and awesome')
# Out:
# {'compound': 0.8519, 'neg': 0.0, 'neu': 0.108, 'pos': 0.892}

# %%
sia.polarity_scores('bad')
# Out:
# {'compound': -0.5423, 'neg': 1.0, 'neu': 0.0, 'pos': 0.0}

# %%
sia.polarity_scores('worst')
# Out:
# {'compound': -0.6249, 'neg': 1.0, 'neu': 0.0, 'pos': 0.0}

# %%
sia.polarity_scores('bad and worst')
# Out:
# {'compound': -0.8225, 'neg': 0.884, 'neu': 0.116, 'pos': 0.0}

# %%
sia.polarity_scores('Umang')
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}

# %%
sia.polarity_scores("This movie was good")
# Out:
# {'compound': 0.4404, 'neg': 0.0, 'neu': 0.508, 'pos': 0.492}

# %%
sia.polarity_scores("This movie was the waste of time and money")
# Out:
# {'compound': -0.4215, 'neg': 0.259, 'neu': 0.741, 'pos': 0.0}

# %%
sia.polarity_scores("good bad")
# Out:
# {'compound': -0.1531, 'neg': 0.547, 'neu': 0.0, 'pos': 0.453}

# %%
sia.polarity_scores("bad good")
# Out:
# {'compound': -0.1531, 'neg': 0.547, 'neu': 0.0, 'pos': 0.453}

# %%
sia.polarity_scores("bad best")
# Out:
# {'compound': 0.1779, 'neg': 0.455, 'neu': 0.0, 'pos': 0.545}

# %%
sia.polarity_scores("worst best")
# Out:
# {'compound': 0.0258, 'neg': 0.494, 'neu': 0.0, 'pos': 0.506}

# %%
sia.polarity_scores('it was the best of times, it was the worst of times')
# Out:
# {'compound': 0.0258, 'neg': 0.224, 'neu': 0.546, 'pos': 0.23}

# %%
sia.polarity_scores('gud')
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0}
